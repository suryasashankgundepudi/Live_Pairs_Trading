# %% [markdown]
# # Backtesting the Strategy
#
# Here we will be looking at how the strategy has performed in the last 6 months and then using this we will decide if we need to move further or not.
#
# One addition to your previous code would be to add another column for the beta between the assets.
#
# This way we can get the hedge ratio.
#
#
# I have made a dummy csv fiole for myself in my data folder and you can use that as reference. Bottom attached is the code.
#
# Here is a task list for those who want to code. Otherwise you can use mine as reference
#
# ## Pairs Trading Strategy with Beta as Hedge Ratio: Task List
# ### Data Preparation and Research
# Asset Pairs Selection: Identify and finalize the list of asset pairs for pairs trading. Record their hedge ratios (beta) based on historical data.
# Data Collection: Research and decide on the data source for real-time or historical price data for selected asset pairs.
# ### Code Development
# Fetch Asset Data: Write code to fetch historical or real-time price data for the selected asset pairs.
# Calculate Spread: Implement logic to calculate the spread between each asset pair using the formula
# Spread = Asset2 − beta × Asset1
# Spread=Asset2−β×Asset1.
# Z-Score Calculation: Calculate the z-score of the spread to standardize it.
# Signal Generation: Generate trading signals based on the calculated z-score. Define upper and lower thresholds for entering and exiting trades.
# Use Beta as Hedge Ratio: Implement logic to use beta as a hedge ratio while placing trades to make the portfolio market-neutral.

# %%
# Importing additional necessary libraries for quant metrics and plotting
from pyfolio.timeseries import perf_stats
import plotly.graph_objs as go
import os
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta
from scipy.stats import zscore
import yfinance as yf
import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
def backtest(df_trading, asset1 : str, asset2 : str, beta: float):
    metrics = {}

    df_trading['spread'] = df_trading[asset2] - beta * df_trading[asset1]
    df_trading['zscore'] = zscore(df_trading['spread'])

    UL = df_trading['zscore'].mean() + df_trading['zscore'].std()
    LL = df_trading['zscore'].mean() - df_trading['zscore'].std()

    holding_position = False  # Flag to indicate if we are holding a position
    df_trading['asset1_signal'] = 0
    df_trading['asset2_signal'] = 0

    for i in range(1, len(df_trading)):
        if not holding_position:
            if df_trading['zscore'].iloc[i] > UL:
                df_trading['asset1_signal'].iloc[i] = -beta
                df_trading['asset2_signal'].iloc[i] = 1
                holding_position = True  # Now holding a position

            elif df_trading['zscore'].iloc[i] < LL:
                df_trading['asset1_signal'].iloc[i] = beta
                df_trading['asset2_signal'].iloc[i] = -1
                holding_position = True  # Now holding a position

        elif holding_position:
            if LL <= df_trading['zscore'].iloc[i] <= UL:
                # Closing the trade
                df_trading['asset1_signal'].iloc[i] = -df_trading['asset1_signal'].iloc[i-1]  # Reverse the last trade
                df_trading['asset2_signal'].iloc[i] = -df_trading['asset2_signal'].iloc[i-1]
                holding_position = False  # No longer holding a position

        # Daily returns
    df_trading['asset1_signal'] = df_trading['asset1_signal'].shift(1)
    df_trading['asset2_signal'] = df_trading['asset2_signal'].shift(1)

    df_trading['asset1_returns'] = df_trading[asset1].pct_change() * df_trading['asset1_signal']
    df_trading['asset2_returns'] = df_trading[asset2].pct_change() * df_trading['asset2_signal']

    df_trading['portfolio_returns'] = df_trading['asset1_returns'] + df_trading['asset2_returns']

    # Quantitative metrics
    stats = perf_stats(df_trading['portfolio_returns'].dropna())
    metrics['CAGR'] = stats['Annual return']
    metrics['Sharpe ratio'] = stats['Sharpe ratio']
    metrics['Max Drawdown'] = stats['Max drawdown']
    metrics['Number of Trades'] = df_trading['asset1_signal'].ne(0).sum()  # Counting non-zero entries

    return metrics, df_trading

# %%
# Function to save the trading signals graph
def save_plotly_graph(df, asset1, asset2):
    # Create directory if it doesn't exist
    if not os.path.exists('img/signals'):
        os.makedirs('img/signals')

    # Create the figure
    fig = go.Figure()

    # Add z-score trace
    fig.add_trace(go.Scatter(x=df.index, y=df['zscore'], mode='lines', name='Z-Score'))

    # Add upper and lower limits as dashed lines
    UL = df['zscore'].mean() + df['zscore'].std()
    LL = df['zscore'].mean() - df['zscore'].std()

    fig.add_trace(go.Scatter(x=df.index, y=[UL]*len(df.index), mode='lines', name='Upper Limit', line=dict(dash='dash')))
    fig.add_trace(go.Scatter(x=df.index, y=[LL]*len(df.index), mode='lines', name='Lower Limit', line=dict(dash='dash')))

    # Add buy and sell signals
    fig.add_trace(go.Scatter(x=df.index, y=df['zscore'].where(df['asset1_signal'] > 0),
                             mode='markers', name='Buy Signal', marker=dict(color='green', symbol='triangle-up')))

    fig.add_trace(go.Scatter(x=df.index, y=df['zscore'].where(df['asset1_signal'] < 0),
                             mode='markers', name='Sell Signal', marker=dict(color='red', symbol='triangle-down')))

    # Layout options
    fig.update_layout(title=f'Trading Signals for {asset1} and {asset2}',
                      xaxis_title='Date',
                      yaxis_title='Z-Score')

    # Save the figure
    fig.write_html(f'img/signals/{asset1}_{asset2}.html')

# %%
# Main function
def main(csv_path: str):
    # Read the CSV file
    asset_pairs = pd.read_csv(csv_path)
    
    # Initialize metrics DataFrame
    metrics_df = pd.DataFrame(columns=['Pair Name', 'CAGR', 'Sharpe Ratio', 'Number of Trades', 'Max Drawdown'])

    # Date range for backtesting (Last 6 months)
    end = datetime.now().date()
    start = (datetime.now() - relativedelta(months=6)).date()

    for index, row in asset_pairs.iterrows():
        asset1 = row['Asset1']
        asset2 = row['Asset2']
        beta = row['Beta']
        print("Running Backtest for Asset Pair {asset2} - {beta} * {asset1}".format(asset1=asset1,asset2=asset2,beta=beta))
        print("Downloading Data")
        # Download data
        asset1_data = yf.download(asset1, start=start, end=end, progress=False)['Adj Close']
        asset2_data = yf.download(asset2, start=start, end=end, progress=False)['Adj Close']

        # DataFrame for backtesting
        df_trading = pd.DataFrame({asset1: asset1_data, asset2: asset2_data})
        print("Running Backtest metrics")
        # Backtest and get metrics and signals
        metrics, signals_df = backtest(df_trading, asset1, asset2, beta)

        new_row = pd.DataFrame({
        'Pair Name': [f'{asset1}_{asset2}'],
        'CAGR': [metrics['CAGR']],
        'Sharpe Ratio': [metrics['Sharpe ratio']],
        'Number of Trades': [metrics['Number of Trades']],
        'Max Drawdown': [metrics['Max Drawdown']]
        })

        metrics_df = pd.concat([metrics_df, new_row], ignore_index=True)


        # Save the Plotly graph
        save_plotly_graph(signals_df, asset1, asset2)

    # Save the metrics DataFrame
    metrics_df.to_csv('data/backtest.csv', index=False)

# %%
main("data/final_pairs.csv")
# Out:
# Running Backtest for Asset Pair ADSK - 1.4007224860731542 * ADYEY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.1913161772535757 * AMAT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 1.05123720468993 * APH
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.5598718604325273 * BSY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.1042792048752494 * CRM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.0657220164142273 * CRWD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - -0.0859833205288776 * CRWD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair APH - 1.1986255721753656 * CSCO
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 1.0585816498166378 * CSCO
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 1.5200881070865322 * CTSH
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.289784860047828 * DDOG
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ACN - 2.6446438656189093 * DELL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 4.66170246287118 * DIDIY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair BSY - 1.012220236506482 * DT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - -0.0331862059040105 * ENPH
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.3022302465920677 * ENTG
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - -3.045945949727613 * ERIC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CRM - 2.695673357846768 * FI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ENPH - -4.889123374643576 * FI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.045122461241194 * FIS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - -0.1507608663351016 * FIS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ERIC - 0.0408729583357434 * FIS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 1.0121390180929832 * FLEX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FIS - -0.3190119646406467 * FSLR
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.3231299443124947 * FTNT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FSLR - 2.2601212552435577 * FTNT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADBE - 13.991685203238548 * FTV
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.9948469800504526 * FTV
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair APH - 0.9432462900902076 * FTV
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 0.6290671470668103 * FTV
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DELL - 1.1710682365852845 * FTV
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 1.4969772502142231 * GDDY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.4642903801823038 * GEN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.2212573493709478 * GFS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 2.9153006662216665 * GLW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 2.255885863664437 * GLW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 1.1371354809610952 * GLW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GFS - 1.9918591181993897 * GLW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 11.66465487373046 * GRAB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 7.44186497595688 * GRAB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 1.7138133322430429 * GRAB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 2.7398093533703944 * HPE
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair APH - 2.972649601062193 * HPE
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.3282820611187824 * HPE
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 2.5236644668983104 * HPQ
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0341722728386269 * HPQ
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.3681543241587762 * IBM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0432919382533938 * IBM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 1.020279436046896 * INFY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GEN - 1.310110830853301 * INFY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ACN - 5.7160856013794525 * INTC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 1.2997630353037009 * INTC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.1224577037086964 * INTC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADBE - 1.8408575606665876 * INTU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair APP - 0.1775737081253154 * INTU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0636437029813951 * INTU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ANET - 3.1075068434427027 * IOT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DT - 0.9078287333863404 * IOT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FI - 1.48051246436074 * IOT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FTNT - 1.3096820859632825 * IOT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0971727282464838 * IOT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.3415476400046232 * IOT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.1568278444316615 * KEYS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.0398871377515736 * LRCX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair BSY - 0.0637086558899453 * LRCX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0058659860944259 * LRCX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0234739334205691 * LRCX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADI - 1.0642654448890094 * LSCC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 0.2442525979136317 * LSCC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FSLR - 1.635136215813607 * LSCC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0001700279580798 * LSCC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.535061907400054 * MCHP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 0.4843599977994419 * MCHP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0498746133639629 * MCHP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.4934798277030363 * MRVL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 0.3221168237898246 * MRVL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0419989418824291 * MRVL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0186044062284285 * MSFT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0561634079141067 * MSFT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair IOT - 0.1411121022232944 * MSFT
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CRM - 4.577785934659401 * MU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DT - 0.9154438624252238 * MU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0417136411062979 * MU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.378487301129391 * MU
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.6039907554939636 * NET
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 4.234151843525868 * NOK
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DDOG - 1.8201987644358075 * NTAP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.031463595180484 * NTAP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FI - 0.0765827694724665 * NVDA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0065498469081269 * NVDA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0186990511737586 * NVDA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair IOT - 0.0484631868311101 * NVDA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MU - 0.0402773159222577 * NVDA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0064047254261293 * NXPI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 0.2415664450538408 * OKTA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.02992315322422 * OKTA
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair BSY - 0.4931370664096622 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DT - 0.4536714051850316 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0241665388399124 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.1770415354794905 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair LRCX - 7.477517546170359 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MU - 0.3837479218652986 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NVDA - 9.040222370905774 * ON
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair AVGO - 8.350398888178589 * ORCL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair BSY - 0.3705057663648513 * ORCL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0297065926603513 * ORCL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.1313594952843314 * ORCL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MU - 0.2825407880765876 * ORCL
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0198306484294388 * PANW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0660443168746417 * PANW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair IOT - 0.1712421688741993 * PANW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NET - 0.1949067050277309 * PANW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ON - 0.3289934170116043 * PANW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.9918232220503246 * PLTR
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.1907134971376176 * PLTR
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.5840443477386508 * PLTR
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0252733869777989 * PSTG
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.6952891301515491 * QCOM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.2857780439539805 * QCOM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.2871364418281139 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair BSY - 0.5042289411649302 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DT - 0.4662292082477698 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FI - 0.7290887034684003 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0245975993571728 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.1620751869908709 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MU - 0.3921417954633995 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ON - 0.8867507942490994 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ORCL - 1.281141123501853 * SHOP
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FTV - 0.049542735558526 * SMCI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0104178039803386 * SMCI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0260838517627673 * SMCI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ON - 0.1320703431343415 * SMCI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0195162420637963 * SNOW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.5486803625620758 * SPLK
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 0.2945842069584367 * SPLK
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GRAB - 0.023738346114027 * SPLK
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NET - 0.5744341590353975 * SPLK
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.6984215604322292 * SQ
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.2558257150367091 * SQ
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GLW - 0.1582850475583648 * SQ
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair QCOM - 0.7098879739008592 * SQ
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FSLR - 3.543918568007077 * STM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0710557111876667 * STM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.9225448972861736 * STX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 0.4920050468355814 * STX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.1567411883862059 * STX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NET - 0.9319312268552508 * STX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair QCOM - 0.703692517384809 * STX
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 0.4215038265066452 * SWKS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0857826645271088 * SWKS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FSLR - 2.002814230550275 * TER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0452901953933135 * TER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GRAB - 0.0220322590350949 * TER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MCHP - 0.7499257603556363 * TER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 3.003529255354718 * TOST
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 1.2850972610882887 * TOST
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 1.0058980119601575 * TRMB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FSLR - -4.024016695488272 * TRMB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.2809216088293498 * TRMB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair QCOM - 1.0800131385256009 * TRMB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.1086420176316647 * TRMB
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 0.2856456998667451 * TSM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0221387701589421 * TSM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GRAB - 0.0209650683935581 * TSM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.1055903122377009 * TSM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair AAPL - 1.427671125341695 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.2438336037494047 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0547148784335953 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.1781159267213332 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTU - 2.60465564645524 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair PANW - 2.473228760937336 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair SNOW - 0.8095298794086909 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.0992599043375296 * TTD
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.5888989307653919 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CDAY - 0.5001731544869238 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.1607990233595302 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GFS - 0.5506858975047906 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GLW - 0.1542384089789197 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair QCOM - 0.5170072115247943 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair SQ - 0.7000131055298661 * TXN
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 1.0057796072992709 * U
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.1476736173810581 * U
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair QCOM - 0.7490688048092264 * U
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair SNOW - 1.9338642879485823 * U
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.2437640215746737 * U
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair AVGO - 19.84128917123469 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 0.4470675865222666 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DT - 0.8174807610725212 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0969360936986838 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.3141370505654637 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MSFT - 5.3518748368414215 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair MU - 0.6749305232544333 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NET - 0.8176273156978247 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ON - 1.7030513767634874 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair PANW - 4.284269326271936 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair PLTR - 0.4989384924448492 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.2239659240888205 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TXN - 0.3476373663825888 * UBER
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.6296554124256415 * UMC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GFS - 4.028525176945783 * UMC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TXN - 6.07419184344452 * UMC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair APH - 0.2571312445345952 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair DELL - 0.3713766259527017 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FTV - 0.281386528630092 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0367906832600284 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.1454116365004118 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.0816285179247869 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TXN - 0.1802127238407121 * VMW
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.124321377129575 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair AMAT - 0.6749417488206911 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair AVGO - 5.013168046924671 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ENPH - -1.7508747640281497 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FI - 0.3250504764912895 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - -0.0106194663230036 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair INTC - 0.0765872710755724 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair IOT - 0.2018231068926054 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NVDA - 4.0689596452693095 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ON - 0.404347528267735 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ORCL - 0.568957078453611 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.0446744041124136 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TXN - 0.128318762042505 * WDAY
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 2.0490282749311124 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair CTSH - 0.909674862999912 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.2828915450360957 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GRAB - 0.0619083055879037 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair NET - 1.3360597964659673 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.4277956991509207 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TXN - 0.863854814225631 * WDC
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - -0.030953539980456 * ZI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair FSLR - -2.892749498997587 * ZI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.096198573526411 * ZI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GFS - -0.2208077789653265 * ZI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - -0.0330526819299683 * ZI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TXN - -0.456126654635725 * ZI
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.8114597822712417 * ZM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.2236469304657867 * ZM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TRMB - 0.6197609622257357 * ZM
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair ADSK - 0.174427206718454 * ZS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GDDY - 0.0073241961820651 * ZS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair GFS - -0.0520451809180682 * ZS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair SNOW - 0.6044690489741321 * ZS
# Downloading Data
# Running Backtest metrics
# Running Backtest for Asset Pair TOST - 0.0453523570883398 * ZS
# Downloading Data
# Running Backtest metrics

# %%
backtest_df = pd.read_csv("data/backtest.csv")

# %%
backtest_df
# Out:
#       Pair Name      CAGR  Sharpe Ratio  Number of Trades  Max Drawdown
# 0    ADYEY_ADSK -0.214021     -2.228692                11     -0.132763
# 1     AMAT_ADSK -0.091438     -1.512107                15     -0.058871
# 2      APH_ADSK  0.042825      0.747717                19     -0.037868
# 3      BSY_ADSK -0.170016     -2.428136                15     -0.102493
# 4      CRM_ADSK  0.111975      1.501138                16     -0.018441
# ..          ...       ...           ...               ...           ...
# 237     ZS_ADSK -0.049191     -0.517104                19     -0.055253
# 238     ZS_GDDY -0.305773     -2.427149                21     -0.171725
# 239      ZS_GFS  0.106874      0.884040                13     -0.040731
# 240     ZS_SNOW -0.218326     -1.910199                13     -0.139259
# 241     ZS_TOST -0.144518     -1.146899                11     -0.118693
#
# [242 rows x 5 columns]
