# %% [markdown]
# Yuki's Code

# %%
import yfinance as yf
import random
import json
import statsmodels.api as sm
import datetime
import os 
import csv
import copy 
from statsmodels.tsa.stattools import adfuller
random.seed(1)

# %% [markdown]
# Load data obtained from the identify pairs notebook

# %%
def load_pairs():
    file_path = "pairs_names.json"
    
    # Read the JSON file as a dictionary
    with open(file_path, "r") as json_file:
        loaded_pairs_dic = json.load(json_file)
    
    # Now, loaded_pairs_dic contains the dictionary from the JSON file
    #print(loaded_pairs_dic)
    return loaded_pairs_dic

# %%
# Enable to use start & end dates:
start = datetime.date.today() - datetime.timedelta(days=430)
end = datetime.date.today() - datetime.timedelta(days=60)

# %% [markdown]
# Plotting price movement of two assets

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go

def plot_assets(asset1, asset2, ticker1, ticker2):
    fig = make_subplots(rows=2,
                    cols=1,
                    subplot_titles=("asset2", "asset1"))

    fig.append_trace(go.Scatter(x=asset2.index,
                                y=asset2,
                                ),
                     row=1, col=1)
    
    fig.append_trace(go.Scatter(x=asset1.index,
                                y=asset1,
                                ),
                     row=2, col=1)
    
    # Update yaxis properties
    fig.update_yaxes(title_text="Price", row=1, col=1)
    fig.update_xaxes(title_text="Date",  row=1, col=1)
    fig.update_yaxes(title_text="Price", row=2, col=1)
    fig.update_xaxes(title_text="Date",  row=2, col=1)
    
    #fig.show()
    if not os.path.exists("img/"):
        os.mkdir("img/")
        print("Image Directory Created!")
    
    file_path = "img/" + ticker1 + "_" + ticker2 + ".html" 
    fig.write_html(file_path)

# %% [markdown]
# Run OLS Regression and calculating spread

# %%
def regression_analysis(asset1, asset2, ticker1, ticker2):

    # adding a constant variable to the asset1 time series for the intercept value 
    asset1 = sm.add_constant(asset1, prepend=False)
    
    # Running the OLS function with asset2 as the dependent variable and asset1 as the dependent variable
    ols = sm.OLS(asset2, asset1)
    
    # Saving the results of the OLS model into a variable
    output = ols.fit()
    print("Completed Training")
    
    #print(output.params)
    # Getting the beta from the OLS results. Close means the close price of asset1
    beta = output.params["Close"]
    
    # Dropping the const column in the dependent variable
    asset1.drop(columns="const", inplace = True)
    
    # Calculating spread
    spread = asset2 - beta*asset1["Close"]
    
    fig = go.Figure(go.Scatter(y = spread))
    
    fig.update_layout(title = "Spread between " + ticker2 + " and " + ticker1)
    
    fig.update_xaxes(title_text="Date")
    fig.update_yaxes(title_text="Spread")
    
    file_path = "img/Spread_" + ticker1 + "_" + ticker2 + ".html"
    fig.write_html(file_path)
    
    #fig.show()
    
    return beta, spread

# %% [markdown]
# Perform Augmented Dickey Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller
def run_adf_test(ticker1, ticker2, spread, pvalue_thres):
    result = adfuller(spread)
    does_pass = result[1] < pvalue_thres
    if does_pass:
        print(f'spread between {ticker1} and {ticker2} passed ADF stationarity test')
    else:
        print(f'spread between {ticker1} and {ticker2} failed ADF stationarity test')    
    return does_pass

# %% [markdown]
# 1.p-value > 0.05: Fail to reject the null hypothesis (H0), the data has a unit root and is non-stationary.
# 2.p-value <= 0.05: Reject the null hypothesis (H0), the data does not have a unit root and is stationary.
# Since the p value is greater than 0.05 we fail to reject the null hypothesis, the time series is not stationary
#
# If it was accepted the code would be as follows
# accepted_pairs = []
# accepted_pairs.append(target_pair[0] + "_" + target_pair[1])
# You don't need to print out the values from ADF just check if the 5% level is less than or equal to 0.05 and save it into the list.
#
# Once the list is complete for all assets you would need to save it as a text file for later use

# %%
def get_data(ticker, start, end):
    return yf.download(ticker, start, end)['Close']

def main():
    final_pair_list = []
    adf_pvalue_thres = 0.05
    pair_to_spread = {} 
    
    pairs_dict = load_pairs()
    print(pairs_dict)

    for ticker1 in pairs_dict.keys():
        tickers = copy.copy(pairs_dict[ticker1])
        if isinstance(tickers, str):
            tickers = [tickers]
            
        for ticker2 in tickers:
            pair_name = ticker1 + '_' + ticker2
            print(pair_name)
            asset1 = get_data(ticker1,start,end)
            asset2 = get_data(ticker2,start,end)
            plot_assets(asset1, asset2, ticker1, ticker2)
            pair_to_spread[pair_name], spread = regression_analysis(asset1, asset2, ticker1, ticker2)
            does_pass_adf = run_adf_test(ticker1,ticker2,spread, adf_pvalue_thres)
            if does_pass_adf:
                final_pair_list.append(ticker1+"_"+ticker2)
    
    print(len(final_pair_list))
    final_pair_file_path = "data/final_pair.csv"
    with open(final_pair_file_path, "w", newline="") as csv_file:
        writer = csv.writer(csv_file)
        for pair in final_pair_list:
            tickers = pair.split("_")
            writer.writerow([tickers[0],tickers[1]])
        
main()
# Out:
# {'COR': ['CAH'], 'CVS': ['BSX', 'CNC'], 'DHR': ['BIIB', 'CNC'], 'DXCM': ['DHR'], 'ELV': ['AMGN'], 'HCA': ['BSX', 'DHR', 'GSK'], 'HLN': ['BSX', 'GSK', 'HCA'], 'HZNP': ['GSK'], 'ILMN': ['GSK', 'HUM'], 'ISRG': ['CAH', 'COR', 'GSK', 'ILMN'], 'JNJ': ['ILMN'], 'LLY': ['CAH', 'GSK', 'ILMN'], 'MDT': ['EW', 'ILMN'], 'MRK': ['GSK', 'ILMN'], 'MRNA': ['A', 'ELV', 'ILMN'], 'NVO': ['BSX', 'DHR', 'GSK', 'HCA', 'HLN', 'ILMN'], 'NVS': ['BSX', 'GSK', 'ILMN'], 'PFE': ['ELV', 'ILMN'], 'RHHBY': ['GSK', 'ILMN'], 'RMD': ['ILMN'], 'SGEN': ['ELV', 'GSK', 'ILMN', 'RMD'], 'SNY': ['BSX', 'DXCM', 'GSK', 'HCA', 'HLN', 'ILMN', 'NVO', 'RMD'], 'SYK': ['BSX', 'CVS', 'DHR', 'GSK', 'HCA', 'HLN', 'ILMN', 'NVO', 'RHHBY', 'RMD', 'SNY'], 'TAK': ['GSK', 'ILMN', 'RMD'], 'TMO': ['GSK', 'ILMN', 'RMD'], 'UNH': ['GSK', 'ILMN', 'RMD'], 'ZBH': ['BSX', 'GSK', 'HCA', 'HLN', 'ILMN', 'RMD', 'SNY'], 'ZTS': ['ELV', 'GSK', 'ILMN', 'RMD']}
# COR_CAH
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between COR and CAH passed ADF stationarity test
# CVS_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between CVS and BSX passed ADF stationarity test
# CVS_CNC
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between CVS and CNC passed ADF stationarity test
# DHR_BIIB
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between DHR and BIIB passed ADF stationarity test
# DHR_CNC
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between DHR and CNC passed ADF stationarity test
# DXCM_DHR
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between DXCM and DHR passed ADF stationarity test
# ELV_AMGN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ELV and AMGN passed ADF stationarity test
# HCA_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HCA and BSX passed ADF stationarity test
# HCA_DHR
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HCA and DHR passed ADF stationarity test
# HCA_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HCA and GSK passed ADF stationarity test
# HLN_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HLN and BSX passed ADF stationarity test
# HLN_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HLN and GSK passed ADF stationarity test
# HLN_HCA
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HLN and HCA passed ADF stationarity test
# HZNP_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between HZNP and GSK passed ADF stationarity test
# ILMN_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ILMN and GSK passed ADF stationarity test
# ILMN_HUM
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ILMN and HUM passed ADF stationarity test
# ISRG_CAH
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ISRG and CAH passed ADF stationarity test
# ISRG_COR
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ISRG and COR passed ADF stationarity test
# ISRG_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ISRG and GSK passed ADF stationarity test
# ISRG_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ISRG and ILMN passed ADF stationarity test
# JNJ_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between JNJ and ILMN passed ADF stationarity test
# LLY_CAH
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between LLY and CAH passed ADF stationarity test
# LLY_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between LLY and GSK passed ADF stationarity test
# LLY_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between LLY and ILMN passed ADF stationarity test
# MDT_EW
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MDT and EW passed ADF stationarity test
# MDT_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MDT and ILMN passed ADF stationarity test
# MRK_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MRK and GSK passed ADF stationarity test
# MRK_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MRK and ILMN passed ADF stationarity test
# MRNA_A
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MRNA and A passed ADF stationarity test
# MRNA_ELV
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MRNA and ELV passed ADF stationarity test
# MRNA_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between MRNA and ILMN passed ADF stationarity test
# NVO_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVO and BSX passed ADF stationarity test
# NVO_DHR
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVO and DHR passed ADF stationarity test
# NVO_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVO and GSK passed ADF stationarity test
# NVO_HCA
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVO and HCA passed ADF stationarity test
# NVO_HLN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVO and HLN passed ADF stationarity test
# NVO_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVO and ILMN passed ADF stationarity test
# NVS_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVS and BSX failed ADF stationarity test
# NVS_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVS and GSK passed ADF stationarity test
# NVS_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between NVS and ILMN passed ADF stationarity test
# PFE_ELV
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between PFE and ELV passed ADF stationarity test
# PFE_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between PFE and ILMN passed ADF stationarity test
# RHHBY_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between RHHBY and GSK passed ADF stationarity test
# RHHBY_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between RHHBY and ILMN passed ADF stationarity test
# RMD_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between RMD and ILMN passed ADF stationarity test
# SGEN_ELV
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SGEN and ELV passed ADF stationarity test
# SGEN_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SGEN and GSK passed ADF stationarity test
# SGEN_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SGEN and ILMN passed ADF stationarity test
# SGEN_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SGEN and RMD passed ADF stationarity test
# SNY_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and BSX passed ADF stationarity test
# SNY_DXCM
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and DXCM passed ADF stationarity test
# SNY_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and GSK passed ADF stationarity test
# SNY_HCA
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and HCA passed ADF stationarity test
# SNY_HLN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and HLN passed ADF stationarity test
# SNY_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and ILMN passed ADF stationarity test
# SNY_NVO
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and NVO passed ADF stationarity test
# SNY_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SNY and RMD passed ADF stationarity test
# SYK_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and BSX passed ADF stationarity test
# SYK_CVS
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and CVS passed ADF stationarity test
# SYK_DHR
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and DHR passed ADF stationarity test
# SYK_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and GSK passed ADF stationarity test
# SYK_HCA
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and HCA passed ADF stationarity test
# SYK_HLN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and HLN passed ADF stationarity test
# SYK_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and ILMN passed ADF stationarity test
# SYK_NVO
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and NVO passed ADF stationarity test
# SYK_RHHBY
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and RHHBY passed ADF stationarity test
# SYK_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and RMD passed ADF stationarity test
# SYK_SNY
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between SYK and SNY passed ADF stationarity test
# TAK_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between TAK and GSK passed ADF stationarity test
# TAK_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between TAK and ILMN passed ADF stationarity test
# TAK_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between TAK and RMD passed ADF stationarity test
# TMO_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between TMO and GSK passed ADF stationarity test
# TMO_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between TMO and ILMN passed ADF stationarity test
# TMO_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between TMO and RMD passed ADF stationarity test
# UNH_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between UNH and GSK passed ADF stationarity test
# UNH_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between UNH and ILMN passed ADF stationarity test
# UNH_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between UNH and RMD passed ADF stationarity test
# ZBH_BSX
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and BSX passed ADF stationarity test
# ZBH_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and GSK passed ADF stationarity test
# ZBH_HCA
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and HCA passed ADF stationarity test
# ZBH_HLN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and HLN passed ADF stationarity test
# ZBH_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and ILMN passed ADF stationarity test
# ZBH_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and RMD passed ADF stationarity test
# ZBH_SNY
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZBH and SNY passed ADF stationarity test
# ZTS_ELV
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZTS and ELV passed ADF stationarity test
# ZTS_GSK
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZTS and GSK passed ADF stationarity test
# ZTS_ILMN
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZTS and ILMN passed ADF stationarity test
# ZTS_RMD
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# Completed Training
# spread between ZTS and RMD passed ADF stationarity test
# 87
